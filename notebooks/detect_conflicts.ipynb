# %%
from database import PostgresStore
import sys
from pathlib import Path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))
from utils.tools import deduplicate_requirements
from models import Modeltypes, ModelFactory
from llama_index.core.llms.llm import LLM
from agents.requirement_extractor import extract_requirements_from_legal_corpus



llm = ModelFactory.getLlmModel(modeltype=Modeltypes.OPENAI)

storage = PostgresStore(
    "postgresql://admin:admin@127.0.0.1:5433",
    "vector_db",
    embedding_dim=768,
)

docstore = storage.get_doc_store("d_parent")

requirements = extract_requirements_from_legal_corpus(
    docstore=docstore,
    llm=llm,
    deduplicate_fn=deduplicate_requirements,
    source_name="GDPR",
    force_reprocess=False,
)
# Out:
# ...
# Found 116 article nodes.
# Cached nodes: 2
# ...
# [1/116]
# Article: /
# Using cached extraction.
# ...
# [2/116]
# Article: /
# Using cached extraction.
# ...
# [3/116]
# Article: /Article 25(6) or Article 26(4) of Directive 95/46/EC. In its/
# Extracted requirements: 7
# ...
# [4/116]
# Article: /Article 267 TFEU as interpreted by the Court of Justice, where it/
# Extracted requirements: 8
# ...
# [5/116]
# Article: /CHAPTER I General provisions/
# Extracted requirements: 0
# ...
# [6/116]
# Article: /CHAPTER I General provisions/Article 1 Subject-matter and objectives/
# Extracted requirements: 0
# ...
# [7/116]
# Article: /CHAPTER I General provisions/Article 2 Material scope/
# Extracted requirements: 0
# ...
# [8/116]
# Article: /CHAPTER I General provisions/Article 3 Territorial scope/
# Extracted requirements: 3
# ...
# [9/116]
# Article: /CHAPTER I General provisions/Article 4 Definitions/
# Extracted requirements: 0
# ...
# [10/116]
# Article: /CHAPTER II Principles/
# Extracted requirements: 15
# ...
# [11/116]
# ...
